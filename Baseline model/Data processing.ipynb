# %% [markdown]
# # GDSC_IC50 Dataset  <span style="color:red">JOIN LATER</span>
# ## Drug response

# %%
import pandas as pd

# %%
# GDSC dataset ~ drug response
df = pd.read_csv("../Dataset/GDSC_IC50.csv")
# delete first column
del df['DATASET']

# %%
df
# Out:
#         NLME_RESULT_ID  NLME_CURVE_ID  COSMIC_ID CELL_LINE_NAME  \
# 0                  342       15580432     684057            ES5
# 1                  342       15580806     684059            ES7
# 2                  342       15581198     684062          EW-11
# 3                  342       15581542     684072        SK-ES-1
# 4                  342       15581930     687448       COLO-829
# ...                ...            ...        ...            ...
# 333156             342       15911377    1659823       SNU-1040
# 333157             342       15912122    1660035         SNU-61
# 333158             342       15912431    1660036         SNU-81
# 333159             342       15912739    1674021         SNU-C5
# 333160             342       15913046    1789883           DiFi
#
#        SANGER_MODEL_ID     TCGA_DESC  DRUG_ID  DRUG_NAME PUTATIVE_TARGET  \
# 0            SIDM00263  UNCLASSIFIED        1  Erlotinib            EGFR
# ...

# %% [markdown]
# --------------------

# %% [markdown]
# # CCLE Datasets

# %%
# Transcriptomics data
ccle_t = pd.read_csv("../Dataset/CCLE_Transcriptomics.csv")
ccle_t = ccle_t.rename({"Unnamed: 0": "Broad_ID"}, axis = 'columns')

# %%
ccle_t
# 1406 rows × 19222 columns
# Out:
#         Broad_ID  TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# 0     ACH-001113       4.331992      0.000000     7.364397       2.792855
# 1     ACH-001289       4.566815      0.584963     7.106537       2.543496
# 2     ACH-001339       3.150560      0.000000     7.379032       2.333424
# 3     ACH-001538       5.085340      0.000000     7.154109       2.545968
# 4     ACH-000242       6.729145      0.000000     6.537607       2.456806
# ...          ...            ...           ...          ...            ...
# 1401  ACH-000285       0.056584      0.000000     6.604071       3.264536
# 1402  ACH-002669       3.109361      0.000000     7.031219       1.541019
# 1403  ACH-001858       4.390943      0.000000     7.013127       1.887525
# 1404  ACH-001997       5.057017      0.000000     7.814935       2.538538
# 1405  ACH-000052       4.247928      0.000000     6.174127       2.316146
#
#       C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  GCLC (2729)  \
# ...

# %% [markdown]
# ### CCLE Proteomics

# %%
ccle_p = pd.read_csv("../Dataset/CCLE_Proteomics.csv")

# %%
ccle_p = ccle_p.rename({"Unnamed: 0": "CCLE_Name"}, axis = 'columns')
ccle_p
# 899 rows × 215 columns
# Out:
#                                     CCLE_Name  14-3-3_beta  \
# 0                                  DMS53_LUNG    -0.104888
# 1                      SW1116_LARGE_INTESTINE     0.358504
# 2                               NCIH1694_LUNG     0.028738
# 3    P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     0.120039
# 4    HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    -0.268997
# ..                                        ...          ...
# 894                               UO31_KIDNEY     0.043231
# 895              SF268_CENTRAL_NERVOUS_SYSTEM    -0.034597
# 896              SF539_CENTRAL_NERVOUS_SYSTEM    -0.250998
# 897              SNB75_CENTRAL_NERVOUS_SYSTEM    -0.139833
# 898                                HOP92_LUNG     0.057413
#
#      14-3-3_epsilon_Caution  14-3-3_zeta    4E-BP1  4E-BP1_pS65  \
# 0                  0.060414     0.309068 -0.075506     0.230359
# 1                 -0.180291    -0.041237 -0.286629    -0.877406
# ...

# %% [markdown]
# ## Cell Lines Map
# This dataset provides the Broad_ID (DepMap_ID) and the Cancer Cell Line name

# %%
mapping = pd.read_csv("../Dataset/DepMap-2018q3-celllines.csv")
mapping.head()
# Out:
#      Broad_ID                                  CCLE_Name  Aliases  COSMIC_ID  \
# 0  ACH-000557  AML193_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  AML-193        NaN
# 1  ACH-001000              1321N1_CENTRAL_NERVOUS_SYSTEM      NaN        NaN
# 2  ACH-000198    EOL1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     EOL1   906856.0
# 3  ACH-000956                             22RV1_PROSTATE   22-RV1   924100.0
# 4  ACH-000948                            2313287_STOMACH  2313287   910924.0
#
#    Sanger ID  Primary Disease          Subtype Disease  Gender Source
# 0        NaN         Leukemia                      NaN  Female   ATCC
# 1        NaN     Brain Cancer                   glioma     NaN    NaN
# 2      426.0         Leukemia  haematopoietic_neoplasm    Male   DSMZ
# 3     1027.0  Prostate Cancer                carcinoma    Male   ATCC
# 4      558.0   Gastric Cancer           adenocarcinoma    Male   DSMZ

# %%
# Find matching of CCLE names between the mapping file & the CCLE proteonomics file

common_values = mapping['CCLE_Name'].isin(ccle_p['CCLE_Name'])
match_count = common_values.sum()  # Counts True values (matches)
print(f"Number of matches: {match_count}")

# 882 / 899 rows can be matched (98%)
# Out:
# Number of matches: 882

# %%
# Find matching of ACH IDs between the mapping file & the CCLE Transcriptomics file

common_values = ccle_t['Broad_ID'].isin(mapping['Broad_ID'])
match_count = common_values.sum()  # Counts True values (matches)
print(f"Number of matches: {match_count}")

# 1227 / 1406 rows can be matched (87%)
# Out:
# Number of matches: 1227
