# %% [markdown]
# # AIM
#
# Trim down the current dataset ~ breast cancer, multi-omics (trans & prot), gdsc1, isosmile (converted to morgan) to both:
#
# 1. Only 1 omics each
# 2. Perform deep learning on each omics to find their values

# %%
import pandas as pd
import numpy as np

# %%
# Read dataset
breast_cancer_multi_omics_gdsc1_iso_m = pd.read_csv("../Dataset/breast_cancer_transcript_proteo_multi_omics_gdsc1_iso_morgan.csv")

breast_cancer_multi_omics_gdsc1_iso_m.drop(columns = ['Unnamed: 0'], inplace=True, axis=1)

# %%
breast_cancer_multi_omics_gdsc1_iso_m.head()
# Out:
#    DRUG_ID    DRUG_NAME     CCLE_Name  COSMIC_ID  TSPAN6 (7105)  TNMD (64102)  \
# 0      133  Doxorubicin  AU565_BREAST     910704       3.428946           0.0
# 1      134    Etoposide  AU565_BREAST     910704       3.428946           0.0
# 2      135  Gemcitabine  AU565_BREAST     910704       3.428946           0.0
# 3      136  Mitomycin-C  AU565_BREAST     910704       3.428946           0.0
# 4      140  Vinorelbine  AU565_BREAST     910704       3.428946           0.0
#
#    DPM1 (8813)  SCYL3 (57147)  C1orf112 (55732)  FGR (2268)  ...  247  248  \
# 0     6.869871       3.500802           4.31904    0.111031  ...    0    0
# 1     6.869871       3.500802           4.31904    0.111031  ...    0    0
# 2     6.869871       3.500802           4.31904    0.111031  ...    0    0
# 3     6.869871       3.500802           4.31904    0.111031  ...    1    0
# 4     6.869871       3.500802           4.31904    0.111031  ...    1    0
#
#    249  250  251  252  253  254  255   LN_IC50
# 0    1    0    1    0    1    0    0 -2.020833
# 1    1    0    1    0    0    0    1  1.047349
# 2    0    1    1    0    0    0    0 -3.499537
# 3    0    0    1    0    0    1    0 -0.633531
# 4    1    1    1    0    0    0    0 -5.551392
#
# [5 rows x 19697 columns]

# %% [markdown]
# -----
