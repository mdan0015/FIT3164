# %%
import pandas as pd

# %%
ccle_transcriptomics = pd.read_csv("/Users/tayqing/Desktop/FIT 3163/drive-download-20250312T160906Z-001/CCLE_expression.csv")

# %%
ccle_transcriptomics
# Out:
#       Unnamed: 0  TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# 0     ACH-001113       4.331992      0.000000     7.364397       2.792855
# 1     ACH-001289       4.566815      0.584963     7.106537       2.543496
# 2     ACH-001339       3.150560      0.000000     7.379032       2.333424
# 3     ACH-001538       5.085340      0.000000     7.154109       2.545968
# 4     ACH-000242       6.729145      0.000000     6.537607       2.456806
# ...          ...            ...           ...          ...            ...
# 1401  ACH-000285       0.056584      0.000000     6.604071       3.264536
# 1402  ACH-002669       3.109361      0.000000     7.031219       1.541019
# 1403  ACH-001858       4.390943      0.000000     7.013127       1.887525
# 1404  ACH-001997       5.057017      0.000000     7.814935       2.538538
# 1405  ACH-000052       4.247928      0.000000     6.174127       2.316146
#
#       C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  GCLC (2729)  \
# ...

# %%
sample_info = pd.read_csv("/Users/tayqing/Desktop/FIT 3163/Previous group/data/sample_info (1).csv")

# %%
sample_info
# Out:
#        DepMap_ID cell_line_name stripped_cell_line_name  \
# 0     ACH-000016         SLR 21                   SLR21
# 1     ACH-000032     MHH-CALL-3                MHHCALL3
# 2     ACH-000033      NCI-H1819                NCIH1819
# 3     ACH-000043       Hs 895.T                  HS895T
# 4     ACH-000049         HEK TE                   HEKTE
# ...          ...            ...                     ...
# 1835  ACH-002393        CRO-AP3                  CROAP3
# 1836  ACH-002394            GEO                     GEO
# 1837  ACH-002395  HuH-6 Clone 5              HUH6CLONE5
# 1838  ACH-002396       Sarc9371                SARC9371
# 1839  ACH-002397          KMH-2                KMHDASH2
#
#                                         CCLE_Name alias   COSMICID     sex  \
# 0                                    SLR21_KIDNEY   NaN        NaN     NaN
# 1     MHHCALL3_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE   NaN        NaN  Female
# ...

# %%
# only keep the necessary columns
sample_info = sample_info[['COSMICID', 'DepMap_ID', 'CCLE_Name', 'primary_disease']]

# %%
sample_info
# Out:
#        COSMICID   DepMap_ID                                    CCLE_Name  \
# 0           NaN  ACH-000016                                 SLR21_KIDNEY
# 1           NaN  ACH-000032  MHHCALL3_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 2           NaN  ACH-000033                                NCIH1819_LUNG
# 3           NaN  ACH-000043                            HS895T_FIBROBLAST
# 4           NaN  ACH-000049                                 HEKTE_KIDNEY
# ...         ...         ...                                          ...
# 1835        NaN  ACH-002393    CROAP3_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 1836        NaN  ACH-002394                          GEO_LARGE_INTESTINE
# 1837        NaN  ACH-002395                             HUH6CLONE5_LIVER
# 1838        NaN  ACH-002396                                SARC9371_BONE
# 1839  2054094.0  ACH-002397                                 KMH2_THYROID
#
#               primary_disease
# 0               Kidney Cancer
# ...

# %%
ccle_transcriptomics = ccle_transcriptomics.rename(columns = {'Unnamed: 0': 'DepMap_ID'}, inplace = False)

# %%
ccle_transcriptomics
# Out:
#        DepMap_ID  TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# 0     ACH-001113       4.331992      0.000000     7.364397       2.792855
# 1     ACH-001289       4.566815      0.584963     7.106537       2.543496
# 2     ACH-001339       3.150560      0.000000     7.379032       2.333424
# 3     ACH-001538       5.085340      0.000000     7.154109       2.545968
# 4     ACH-000242       6.729145      0.000000     6.537607       2.456806
# ...          ...            ...           ...          ...            ...
# 1401  ACH-000285       0.056584      0.000000     6.604071       3.264536
# 1402  ACH-002669       3.109361      0.000000     7.031219       1.541019
# 1403  ACH-001858       4.390943      0.000000     7.013127       1.887525
# 1404  ACH-001997       5.057017      0.000000     7.814935       2.538538
# 1405  ACH-000052       4.247928      0.000000     6.174127       2.316146
#
#       C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  GCLC (2729)  \
# ...

# %%
# merge sample info dataset witht CCLE transcriptomic dataset
ccle_transcriptomics = pd.merge(ccle_transcriptomics, sample_info, on=['DepMap_ID'], how = 'left')

# %%
ccle_transcriptomics
# Out:
#        DepMap_ID  TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# 0     ACH-001113       4.331992      0.000000     7.364397       2.792855
# 1     ACH-001289       4.566815      0.584963     7.106537       2.543496
# 2     ACH-001339       3.150560      0.000000     7.379032       2.333424
# 3     ACH-001538       5.085340      0.000000     7.154109       2.545968
# 4     ACH-000242       6.729145      0.000000     6.537607       2.456806
# ...          ...            ...           ...          ...            ...
# 1401  ACH-000285       0.056584      0.000000     6.604071       3.264536
# 1402  ACH-002669       3.109361      0.000000     7.031219       1.541019
# 1403  ACH-001858       4.390943      0.000000     7.013127       1.887525
# 1404  ACH-001997       5.057017      0.000000     7.814935       2.538538
# 1405  ACH-000052       4.247928      0.000000     6.174127       2.316146
#
#       C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  GCLC (2729)  \
# ...

# %%
CCLE_Proteomics = pd.read_csv("/Users/tayqing/Desktop/FIT 3163/drive-download-20250312T160906Z-001/CCLE_RPPA_20181003.csv")

# %%
CCLE_Proteomics
# Out:
#                                    Unnamed: 0  14-3-3_beta  \
# 0                                  DMS53_LUNG    -0.104888
# 1                      SW1116_LARGE_INTESTINE     0.358504
# 2                               NCIH1694_LUNG     0.028738
# 3    P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     0.120039
# 4    HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    -0.268997
# ..                                        ...          ...
# 894                               UO31_KIDNEY     0.043231
# 895              SF268_CENTRAL_NERVOUS_SYSTEM    -0.034597
# 896              SF539_CENTRAL_NERVOUS_SYSTEM    -0.250998
# 897              SNB75_CENTRAL_NERVOUS_SYSTEM    -0.139833
# 898                                HOP92_LUNG     0.057413
#
#      14-3-3_epsilon_Caution  14-3-3_zeta    4E-BP1  4E-BP1_pS65  \
# 0                  0.060414     0.309068 -0.075506     0.230359
# 1                 -0.180291    -0.041237 -0.286629    -0.877406
# ...

# %%
CCLE_Proteomics = CCLE_Proteomics.rename(columns = {'Unnamed: 0': 'CCLE_Name'}, inplace = False)

# %%
CCLE_Proteomics
# Out:
#                                     CCLE_Name  14-3-3_beta  \
# 0                                  DMS53_LUNG    -0.104888
# 1                      SW1116_LARGE_INTESTINE     0.358504
# 2                               NCIH1694_LUNG     0.028738
# 3    P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     0.120039
# 4    HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    -0.268997
# ..                                        ...          ...
# 894                               UO31_KIDNEY     0.043231
# 895              SF268_CENTRAL_NERVOUS_SYSTEM    -0.034597
# 896              SF539_CENTRAL_NERVOUS_SYSTEM    -0.250998
# 897              SNB75_CENTRAL_NERVOUS_SYSTEM    -0.139833
# 898                                HOP92_LUNG     0.057413
#
#      14-3-3_epsilon_Caution  14-3-3_zeta    4E-BP1  4E-BP1_pS65  \
# 0                  0.060414     0.309068 -0.075506     0.230359
# 1                 -0.180291    -0.041237 -0.286629    -0.877406
# ...

# %%
# merge CCLE proteomics with sample info
CCLE_Proteomics = pd.merge(CCLE_Proteomics, sample_info, on=['CCLE_Name'], how = 'left')

# %%
CCLE_Proteomics
# Out:
#                                     CCLE_Name  14-3-3_beta  \
# 0                                  DMS53_LUNG    -0.104888
# 1                      SW1116_LARGE_INTESTINE     0.358504
# 2                               NCIH1694_LUNG     0.028738
# 3    P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     0.120039
# 4    HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    -0.268997
# ..                                        ...          ...
# 894                               UO31_KIDNEY     0.043231
# 895              SF268_CENTRAL_NERVOUS_SYSTEM    -0.034597
# 896              SF539_CENTRAL_NERVOUS_SYSTEM    -0.250998
# 897              SNB75_CENTRAL_NERVOUS_SYSTEM    -0.139833
# 898                                HOP92_LUNG     0.057413
#
#      14-3-3_epsilon_Caution  14-3-3_zeta    4E-BP1  4E-BP1_pS65  \
# 0                  0.060414     0.309068 -0.075506     0.230359
# 1                 -0.180291    -0.041237 -0.286629    -0.877406
# ...

# %%
# drop the DepMap_ID column 
to_drop = ['DepMap_ID']
ccle_transcriptomics.drop(to_drop, inplace = True, axis = 1)

# %%
ccle_transcriptomics
# Out:
#       TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# 0          4.331992      0.000000     7.364397       2.792855
# 1          4.566815      0.584963     7.106537       2.543496
# 2          3.150560      0.000000     7.379032       2.333424
# 3          5.085340      0.000000     7.154109       2.545968
# 4          6.729145      0.000000     6.537607       2.456806
# ...             ...           ...          ...            ...
# 1401       0.056584      0.000000     6.604071       3.264536
# 1402       3.109361      0.000000     7.031219       1.541019
# 1403       4.390943      0.000000     7.013127       1.887525
# 1404       5.057017      0.000000     7.814935       2.538538
# 1405       4.247928      0.000000     6.174127       2.316146
#
#       C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  GCLC (2729)  \
# 0             4.470537    0.028569    1.226509      3.042644     6.499686
# ...

# %%
CCLE_Proteomics.drop(to_drop, inplace = True, axis = 1)

# %%
CCLE_Proteomics
# Out:
#                                     CCLE_Name  14-3-3_beta  \
# 0                                  DMS53_LUNG    -0.104888
# 1                      SW1116_LARGE_INTESTINE     0.358504
# 2                               NCIH1694_LUNG     0.028738
# 3    P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     0.120039
# 4    HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    -0.268997
# ..                                        ...          ...
# 894                               UO31_KIDNEY     0.043231
# 895              SF268_CENTRAL_NERVOUS_SYSTEM    -0.034597
# 896              SF539_CENTRAL_NERVOUS_SYSTEM    -0.250998
# 897              SNB75_CENTRAL_NERVOUS_SYSTEM    -0.139833
# 898                                HOP92_LUNG     0.057413
#
#      14-3-3_epsilon_Caution  14-3-3_zeta    4E-BP1  4E-BP1_pS65  \
# 0                  0.060414     0.309068 -0.075506     0.230359
# 1                 -0.180291    -0.041237 -0.286629    -0.877406
# ...

# %%
cell_line_name = ccle_transcriptomics[['CCLE_Name']]

# %%
cell_line_name
# Out:
#                                       CCLE_Name
# 0                                  LC1SQSF_LUNG
# 1                          COGAR359_SOFT_TISSUE
# 2                                  COLO794_SKIN
# 3                          KKU213_BILIARY_TRACT
# 4                             RT4_URINARY_TRACT
# ...                                         ...
# 1401  TOLEDO_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 1402                               KP363T_COLON
# 1403                        SSP25_BILIARY_TRACT
# 1404                         ECC2_BILIARY_TRACT
# 1405                                  A673_BONE
#
# [1406 rows x 1 columns]

# %%
# Rename the 'CCLE_Name' column to 'Cell_Line_Name' in cell_line_name DataFrame
cell_line_name = cell_line_name.rename(columns = {'CCLE_Name':'Cell_Line_Name'}, inplace = False)

# %%
cell_line_name
# Out:
#                                  Cell_Line_Name
# 0                                  LC1SQSF_LUNG
# 1                          COGAR359_SOFT_TISSUE
# 2                                  COLO794_SKIN
# 3                          KKU213_BILIARY_TRACT
# 4                             RT4_URINARY_TRACT
# ...                                         ...
# 1401  TOLEDO_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE
# 1402                               KP363T_COLON
# 1403                        SSP25_BILIARY_TRACT
# 1404                         ECC2_BILIARY_TRACT
# 1405                                  A673_BONE
#
# [1406 rows x 1 columns]

# %%
# Convert 'Cell_Line_Name' column values to list
cell_line_name_lst = cell_line_name['Cell_Line_Name'].values.tolist()

# %%
cell_line_name_lst
# Out:
# ['LC1SQSF_LUNG',
#  'COGAR359_SOFT_TISSUE',
#  'COLO794_SKIN',
#  'KKU213_BILIARY_TRACT',
#  'RT4_URINARY_TRACT',
#  'SNU283_LARGE_INTESTINE',
#  'NCIH1395_LUNG',
#  'DEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#  'SNU1196_BILIARY_TRACT',
#  'LC1F_LUNG',
#  '93T449_SOFT_TISSUE',
#  'TGBC18TKB_LARGE_INTESTINE',
#  'ABC1_LUNG',
#  'SKN_ENDOMETRIUM',
#  'KE97_STOMACH',
#  'BFTC909_KIDNEY',
#  'KCIMOH1_PANCREAS',
#  'YKG1_CENTRAL_NERVOUS_SYSTEM',
#  'MKN1_STOMACH',
#  'LK2_LUNG',
#  'HS888T_FIBROBLAST',
#  'ZR7530_BREAST',
#  'SW837_LARGE_INTESTINE',
#  'WM983B_SKIN',
#  'PACADD119_PANCREAS',
#  'A101D_SKIN',
#  'OS252_BONE',
#  'NCIH446_LUNG',
#  'PECAPJ34CLONEC12_UPPER_AERODIGESTIVE_TRACT',
#  'TUHR14TKB_KIDNEY',
#  'COV434_OVARY',
#  'YD10B_UPPER_AERODIGESTIVE_TRACT',
#  'HSSCH2_CENTRAL_NERVOUS_SYSTEM',
#  'KKU100_BILIARY_TRACT',
#  'KMRC3_KIDNEY',
#  'HOKUG_CERVIX',
#  'KASUMI2_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE',
#  'NCIH2882_LUNG',
#  'KYSE140_OESOPHAGUS',
#  'MKN7_STOMACH',
# ...

# %%
ccle_transcriptomics.insert(loc=0, column='Cell_Line_Name', value = cell_line_name_lst)

# %%
ccle_transcriptomics
# Out:
#                                  Cell_Line_Name  TSPAN6 (7105)  TNMD (64102)  \
# 0                                  LC1SQSF_LUNG       4.331992      0.000000
# 1                          COGAR359_SOFT_TISSUE       4.566815      0.584963
# 2                                  COLO794_SKIN       3.150560      0.000000
# 3                          KKU213_BILIARY_TRACT       5.085340      0.000000
# 4                             RT4_URINARY_TRACT       6.729145      0.000000
# ...                                         ...            ...           ...
# 1401  TOLEDO_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       0.056584      0.000000
# 1402                               KP363T_COLON       3.109361      0.000000
# 1403                        SSP25_BILIARY_TRACT       4.390943      0.000000
# 1404                         ECC2_BILIARY_TRACT       5.057017      0.000000
# 1405                                  A673_BONE       4.247928      0.000000
#
# ...

# %%
to_drop = ['CCLE_Name']
ccle_transcriptomics.drop(to_drop, inplace=True, axis =1)

# %%
ccle_transcriptomics
# Out:
#                                  Cell_Line_Name  TSPAN6 (7105)  TNMD (64102)  \
# 0                                  LC1SQSF_LUNG       4.331992      0.000000
# 1                          COGAR359_SOFT_TISSUE       4.566815      0.584963
# 2                                  COLO794_SKIN       3.150560      0.000000
# 3                          KKU213_BILIARY_TRACT       5.085340      0.000000
# 4                             RT4_URINARY_TRACT       6.729145      0.000000
# ...                                         ...            ...           ...
# 1401  TOLEDO_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       0.056584      0.000000
# 1402                               KP363T_COLON       3.109361      0.000000
# 1403                        SSP25_BILIARY_TRACT       4.390943      0.000000
# 1404                         ECC2_BILIARY_TRACT       5.057017      0.000000
# 1405                                  A673_BONE       4.247928      0.000000
#
# ...

# %%
# Extract 'COSMICID' column from ccle_gene_exp DataFrame and create a new DataFrame
cosmic_id = ccle_transcriptomics[['COSMICID']]

# Rename the 'COSMICID' column to 'COSMIC_ID' in cosmic_id DataFrame
cosmic_id = cosmic_id.rename(columns = {'COSMICID':'COSMIC_ID'}, inplace = False)

# Extract 'COSMIC_ID' column values to list
cosmic_id_lst = cosmic_id['COSMIC_ID'].values.tolist()

# Insert 'COSMIC_ID' column at the beginning of ccle_gene_exp DataFrame
ccle_transcriptomics.insert(loc = 0,
                     column = 'COSMIC_ID',
                     value = cosmic_id_lst)


to_drop = ['COSMICID']

# Drop the 'COSMICID' column from ccle_gene_exp DataFrame
ccle_transcriptomics.drop(to_drop, inplace=True, axis=1)

# %%
# Rename columns 'Cell_Line_Name' and 'primary_disease' to 'CCLE_Name' and 'Cancer_Type' respectively
ccle_transcriptomics = ccle_transcriptomics.rename(columns = {'Cell_Line_Name':'CCLE_Name'}, inplace = False)
ccle_transcriptomics = ccle_transcriptomics.rename(columns = {'primary_disease':'Cancer_Type'}, inplace = False)

# %%
# Drop rows with missing values (NaN) from ccle_gene_exp DataFrame
ccle_transcriptomics =  ccle_transcriptomics.dropna(axis='index')

# %%
import numpy as np
# Convert 'COSMIC_ID' column values to int64 data type
ccle_transcriptomics['COSMIC_ID'] = ccle_transcriptomics['COSMIC_ID'].apply(np.int64)

# %%
ccle_transcriptomics
# Out:
#       COSMIC_ID                               CCLE_Name  TSPAN6 (7105)  \
# 4        687455                       RT4_URINARY_TRACT       6.729145
# 5       1659929                  SNU283_LARGE_INTESTINE       4.272023
# 6        684681                           NCIH1395_LUNG       3.337711
# 7        906836  DEL_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE       0.056584
# 12       906791                               ABC1_LUNG       4.512227
# ...         ...                                     ...            ...
# 1394    1240218                         SU8686_PANCREAS       3.263034
# 1396     908441                            NCCIT_TESTIS       6.344828
# 1398     906798                      639V_URINARY_TRACT       4.328406
# 1400     905974                            LOXIMVI_SKIN       3.533563
# 1405     684052                               A673_BONE       4.247928
#
#       TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  C1orf112 (55732)  FGR (2268)  \
# ...

# %%
#Extract data which cancer type is breast cancer
ccle_transcriptomics_breast_cancer_data = ccle_transcriptomics[ccle_transcriptomics['Cancer_Type']== 'Breast Cancer']

# %%
ccle_transcriptomics_breast_cancer_data
# Out:
#       COSMIC_ID           CCLE_Name  TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  \
# 21       909907       ZR7530_BREAST       3.472488      0.000000     5.959306
# 54      1290798      EFM192A_BREAST       3.444932      0.056584     7.722193
# 64       909778      UACC893_BREAST       3.988230      0.000000     6.234195
# 72       749717        HCC38_BREAST       3.934517      0.000000     6.519479
# 74       949093        BT483_BREAST       3.528571      0.000000     6.583308
# 81       910927        CAL51_BREAST       5.705425      0.000000     6.413289
# 112      749714      HCC1937_BREAST       4.903038      0.000000     7.177719
# 145      905946         MCF7_BREAST       2.403268      0.000000     7.490249
# 147      906851        EFM19_BREAST       3.485427      0.028569     6.984134
# 171     1290906       HCC202_BREAST       3.049631      0.000000     6.811214
# 200     1290922        HDQP1_BREAST       4.498251      0.000000     6.052459
# ...

# %%
CCLE_Proteomics
# Out:
#                                     CCLE_Name  14-3-3_beta  \
# 0                                  DMS53_LUNG    -0.104888
# 1                      SW1116_LARGE_INTESTINE     0.358504
# 2                               NCIH1694_LUNG     0.028738
# 3    P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     0.120039
# 4    HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    -0.268997
# ..                                        ...          ...
# 894                               UO31_KIDNEY     0.043231
# 895              SF268_CENTRAL_NERVOUS_SYSTEM    -0.034597
# 896              SF539_CENTRAL_NERVOUS_SYSTEM    -0.250998
# 897              SNB75_CENTRAL_NERVOUS_SYSTEM    -0.139833
# 898                                HOP92_LUNG     0.057413
#
#      14-3-3_epsilon_Caution  14-3-3_zeta    4E-BP1  4E-BP1_pS65  \
# 0                  0.060414     0.309068 -0.075506     0.230359
# 1                 -0.180291    -0.041237 -0.286629    -0.877406
# ...

# %%
# change Proteomics cosmic_id to COSMICID and place to the first column
cosmic_id = CCLE_Proteomics[['COSMICID']]
cosmic_id = cosmic_id.rename(columns = {'COSMICID':'COSMIC_ID'}, inplace = False)
cosmic_id_lst = cosmic_id['COSMIC_ID'].values.tolist()
CCLE_Proteomics.insert(loc = 0,
                     column = 'COSMIC_ID',
                     value = cosmic_id_lst)

to_drop = ['COSMICID']
CCLE_Proteomics.drop(to_drop, inplace=True, axis=1)
CCLE_Proteomics = CCLE_Proteomics.rename(columns = {'primary_disease':'Cancer_Type'}, inplace = False)
CCLE_Proteomics = CCLE_Proteomics.dropna(axis='index')
CCLE_Proteomics['COSMIC_ID'] = CCLE_Proteomics['COSMIC_ID'].apply(np.int64)
ccle_proteomics_breast_cancer_data = CCLE_Proteomics[CCLE_Proteomics['Cancer_Type']== 'Breast Cancer']

# %%
ccle_proteomics_breast_cancer_data
# Out:
#      COSMIC_ID           CCLE_Name  14-3-3_beta  14-3-3_epsilon_Caution  \
# 57      749717        HCC38_BREAST     0.032665               -0.258639
# 58      906844       DU4475_BREAST    -0.179600                0.139040
# 63      908120  MDAMB175VII_BREAST     0.037009               -0.017792
# 80      905945         T47D_BREAST     0.046212                0.131015
# 153     905960     MDAMB231_BREAST     0.140073               -0.249335
# 203     749716      HCC2218_BREAST     0.167035                0.008118
# 235     749709      HCC1954_BREAST     0.340273               -0.297638
# 236     946382        CAMA1_BREAST     0.395372                0.059579
# 266     910704        AU565_BREAST     0.061856                0.026326
# 277     905957       HS578T_BREAST     0.128818                0.276849
# 278     906801         BT20_BREAST     0.151272               -0.026378
# 282     908121     MDAMB361_BREAST     0.113090               -0.036075
# ...

# %% [markdown]
# PreProcessing of GDSC drug response

# %%
gdsc_ic50 = pd.read_csv("/Users/tayqing/Desktop/FIT 3163/drive-download-20250312T160906Z-001/GDSC1_fitted_dose_response_27Oct23.csv")

# %%
gdsc_ic50
# Out:
#        DATASET  NLME_RESULT_ID  NLME_CURVE_ID  COSMIC_ID CELL_LINE_NAME  \
# 0        GDSC1             342       15580432     684057            ES5
# 1        GDSC1             342       15580806     684059            ES7
# 2        GDSC1             342       15581198     684062          EW-11
# 3        GDSC1             342       15581542     684072        SK-ES-1
# 4        GDSC1             342       15581930     687448       COLO-829
# ...        ...             ...            ...        ...            ...
# 333156   GDSC1             342       15911377    1659823       SNU-1040
# 333157   GDSC1             342       15912122    1660035         SNU-61
# 333158   GDSC1             342       15912431    1660036         SNU-81
# 333159   GDSC1             342       15912739    1674021         SNU-C5
# 333160   GDSC1             342       15913046    1789883           DiFi
#
#        SANGER_MODEL_ID     TCGA_DESC  DRUG_ID  DRUG_NAME PUTATIVE_TARGET  \
# ...

# %%
# Extract the relevant columns only 
gdsc_ic50 = gdsc_ic50[['DRUG_ID', 'COSMIC_ID', 'DRUG_NAME', 'LN_IC50']]

# %%
gdsc_ic50
# Out:
#         DRUG_ID  COSMIC_ID  DRUG_NAME   LN_IC50
# 0             1     684057  Erlotinib  3.966813
# 1             1     684059  Erlotinib  2.692090
# 2             1     684062  Erlotinib  2.477990
# 3             1     684072  Erlotinib  2.033564
# 4             1     687448  Erlotinib  2.966007
# ...         ...        ...        ...       ...
# 333156     1531    1659823   I-CBP112  5.085294
# 333157     1531    1660035   I-CBP112  5.725399
# 333158     1531    1660036   I-CBP112  4.930753
# 333159     1531    1674021   I-CBP112  4.551784
# 333160     1531    1789883   I-CBP112  4.681069
#
# [333161 rows x 4 columns]

# %%
# merge ccle_transriptomics_breast_cancer data with the gdsc_ic50 data on COSMIC_ID
gdsc_ic50 = pd.merge(ccle_transcriptomics_breast_cancer_data, gdsc_ic50, on= ['COSMIC_ID'], how = 'left')

# %%
gdsc_ic50
# Out:
#        COSMIC_ID        CCLE_Name  TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  \
# 0         909907    ZR7530_BREAST       3.472488           0.0     5.959306
# 1         909907    ZR7530_BREAST       3.472488           0.0     5.959306
# 2         909907    ZR7530_BREAST       3.472488           0.0     5.959306
# 3         909907    ZR7530_BREAST       3.472488           0.0     5.959306
# 4         909907    ZR7530_BREAST       3.472488           0.0     5.959306
# ...          ...              ...            ...           ...          ...
# 15215     908121  MDAMB361_BREAST       1.855990           0.0     6.736740
# 15216     908121  MDAMB361_BREAST       1.855990           0.0     6.736740
# 15217     908121  MDAMB361_BREAST       1.855990           0.0     6.736740
# 15218     908121  MDAMB361_BREAST       1.855990           0.0     6.736740
# 15219     908121  MDAMB361_BREAST       1.855990           0.0     6.736740
#
# ...

# %%
to_drop = ['Cancer_Type']
gdsc_ic50.drop(to_drop, inplace= True, axis = 1)

# %%
gdsc_ic50
# Out:
#        COSMIC_ID        CCLE_Name  TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  \
# 0         909907    ZR7530_BREAST       3.472488           0.0     5.959306
# 1         909907    ZR7530_BREAST       3.472488           0.0     5.959306
# 2         909907    ZR7530_BREAST       3.472488           0.0     5.959306
# 3         909907    ZR7530_BREAST       3.472488           0.0     5.959306
# 4         909907    ZR7530_BREAST       3.472488           0.0     5.959306
# ...          ...              ...            ...           ...          ...
# 15215     908121  MDAMB361_BREAST       1.855990           0.0     6.736740
# 15216     908121  MDAMB361_BREAST       1.855990           0.0     6.736740
# 15217     908121  MDAMB361_BREAST       1.855990           0.0     6.736740
# 15218     908121  MDAMB361_BREAST       1.855990           0.0     6.736740
# 15219     908121  MDAMB361_BREAST       1.855990           0.0     6.736740
#
# ...

# %%
gdsc_ic50 = gdsc_ic50.dropna(axis='index')

# %%
# Extract 'DRUG_ID' column values to list
cells_value = gdsc_ic50['DRUG_ID'].values.tolist()
to_drop = ['DRUG_ID']
# Drop the 'DRUG_ID' column from gdsc DataFrame
gdsc_ic50.drop(to_drop, inplace=True, axis=1)

# Insert 'DRUG_ID' column at the beginning of gdsc DataFrame
gdsc_ic50.insert(loc = 0,
          column = 'DRUG_ID',
          value = cells_value)


# Extract 'DRUG_NAME' column values to list
cells_value = gdsc_ic50['DRUG_NAME'].values.tolist()
to_drop = ['DRUG_NAME']

# Drop the 'DRUG_NAME' column from gene_drug_response DataFrame
gdsc_ic50.drop(to_drop, inplace=True, axis=1)
# Insert 'DRUG_NAME' column at the beginning of gene_drug_response DataFrame
gdsc_ic50.insert(loc = 0,
          column = 'DRUG_NAME',
          value = cells_value)

# %%
gdsc_ic50
# Out:
#           DRUG_NAME  DRUG_ID  COSMIC_ID        CCLE_Name  TSPAN6 (7105)  \
# 0       Doxorubicin      133     909907    ZR7530_BREAST       3.472488
# 1         Etoposide      134     909907    ZR7530_BREAST       3.472488
# 2       Gemcitabine      135     909907    ZR7530_BREAST       3.472488
# 3       Mitomycin-C      136     909907    ZR7530_BREAST       3.472488
# 4       Vinorelbine      140     909907    ZR7530_BREAST       3.472488
# ...             ...      ...        ...              ...            ...
# 15215   Refametinib     1526     908121  MDAMB361_BREAST       1.855990
# 15216    Pictilisib     1527     908121  MDAMB361_BREAST       1.855990
# 15217  Pevonedistat     1529     908121  MDAMB361_BREAST       1.855990
# 15218         PFI-3     1530     908121  MDAMB361_BREAST       1.855990
# 15219      I-CBP112     1531     908121  MDAMB361_BREAST       1.855990
#
#        TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  C1orf112 (55732)  FGR (2268)  \
# ...

# %%
# gdscic50 merge with proteomics dataset
gdsc_ic50_proteomics = pd.merge(ccle_proteomics_breast_cancer_data, gdsc_ic50, on= ['COSMIC_ID'], how = 'left')

# %%
gdsc_ic50_proteomics
# Out:
#        COSMIC_ID     CCLE_Name  14-3-3_beta_x  14-3-3_epsilon_Caution_x  \
# 0         749717  HCC38_BREAST       0.032665                 -0.258639
# 1         749717  HCC38_BREAST       0.032665                 -0.258639
# 2         749717  HCC38_BREAST       0.032665                 -0.258639
# 3         749717  HCC38_BREAST       0.032665                 -0.258639
# 4         749717  HCC38_BREAST       0.032665                 -0.258639
# ...          ...           ...            ...                       ...
# 14127    1298157  JIMT1_BREAST      -0.016883                 -0.329187
# 14128    1298157  JIMT1_BREAST      -0.016883                 -0.329187
# 14129    1298157  JIMT1_BREAST      -0.016883                 -0.329187
# 14130    1298157  JIMT1_BREAST      -0.016883                 -0.329187
# 14131    1298157  JIMT1_BREAST      -0.016883                 -0.329187
#
#        14-3-3_zeta_x  4E-BP1_x  4E-BP1_pS65_x  4E-BP1_pT37_T46_x  \
# ...

# %%
gdsc_ic50_proteomics = gdsc_ic50_proteomics.dropna(axis='index')

# %%
gdsc_ic50_proteomics = gdsc_ic50_proteomics.dropna(axis='index')

# %%
# Extract 'DRUG_ID' column values to list
cells_value = gdsc_ic50_proteomics['DRUG_ID'].values.tolist()
to_drop = ['DRUG_ID']
# Drop the 'DRUG_ID' column from gdsc DataFrame
gdsc_ic50_proteomics.drop(to_drop, inplace=True, axis=1)

# Insert 'DRUG_ID' column at the beginning of gdsc DataFrame
gdsc_ic50_proteomics.insert(loc = 0,
          column = 'DRUG_ID',
          value = cells_value)


# Extract 'DRUG_NAME' column values to list
cells_value = gdsc_ic50_proteomics['DRUG_NAME'].values.tolist()
to_drop = ['DRUG_NAME']

# Drop the 'DRUG_NAME' column from gene_drug_response DataFrame
gdsc_ic50_proteomics.drop(to_drop, inplace=True, axis=1)
# Insert 'DRUG_NAME' column at the beginning of gene_drug_response DataFrame
gdsc_ic50_proteomics.insert(loc = 0,
          column = 'DRUG_NAME',
          value = cells_value)

# %%
gdsc_ic50_proteomics
# Out:
#           DRUG_NAME  DRUG_ID  COSMIC_ID     CCLE_Name  14-3-3_beta_x  \
# 0       Doxorubicin      133     749717  HCC38_BREAST       0.032665
# 1         Etoposide      134     749717  HCC38_BREAST       0.032665
# 2       Gemcitabine      135     749717  HCC38_BREAST       0.032665
# 3       Mitomycin-C      136     749717  HCC38_BREAST       0.032665
# 4       Vinorelbine      140     749717  HCC38_BREAST       0.032665
# ...             ...      ...        ...           ...            ...
# 14127  Bicalutamide     1502    1298157  JIMT1_BREAST      -0.016883
# 14128   Refametinib     1526    1298157  JIMT1_BREAST      -0.016883
# 14129    Pictilisib     1527    1298157  JIMT1_BREAST      -0.016883
# 14130         PFI-3     1530    1298157  JIMT1_BREAST      -0.016883
# 14131      I-CBP112     1531    1298157  JIMT1_BREAST      -0.016883
#
#        14-3-3_epsilon_Caution_x  14-3-3_zeta_x  4E-BP1_x  4E-BP1_pS65_x  \
# ...

# %% [markdown]
# Drug data

# %%
pip install rdkit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 2.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 23.8 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
drug = pd.read_csv("/Users/tayqing/Desktop/FIT 3163/drive-download-20250312T160906Z-001/Drug_Info.csv")

# %%
drug
# Out:
#      Drug Id                       Name                     Synonyms  \
# 0       1242          (5Z)-7-Oxozeaenol  5Z-7-Oxozeaenol, LL-Z1640-2
# 1       1824                     123138                          NaN
# 2       1820                     123829                          NaN
# 3       1836                     150412                          NaN
# 4        179             5-Fluorouracil                         5-FU
# ..       ...                        ...                          ...
# 695      409  eEF2K Inhibitor, A-484954                          NaN
# 696     2439                glutathione                 G6013, sigma
# 697      407               kb NB 142-70                          NaN
# 698     1261                     rTRAIL                          NaN
# 699     1202                     torin2                          NaN
#
#                         Targets        Target pathway  PubCHEM  Datasets  \
# ...

# %%
# rename the columns 'PubCHEM' and 'Drug id' in drug DataFrame
drug = drug.rename(columns = {' PubCHEM':'PubCHEM'}, inplace = False)
drug = drug.rename(columns = {'Drug Id':'DRUG_ID'}, inplace = False)

# %%
drug_clean = drug[['DRUG_ID', 'PubCHEM']]

# %%
drug_clean
# Out:
#      DRUG_ID  PubCHEM
# 0       1242  9863776
# 1       1824      NaN
# 2       1820      NaN
# 3       1836      NaN
# 4        179     3385
# ..       ...      ...
# 695      409      NaN
# 696     2439      NaN
# 697      407      NaN
# 698     1261     none
# 699     1202      NaN
#
# [700 rows x 2 columns]

# %%
# Filter out rows where 'PubCHEM' column values are not numeric
drug_clean = drug_clean[drug_clean['PubCHEM'].apply(lambda x: str(x).isdigit())]

# %%
drug_clean
# Out:
#      DRUG_ID   PubCHEM
# 0       1242   9863776
# 4        179      3385
# 5       1073      3385
# 20        86  10172943
# 21        55   9549184
# ..       ...       ...
# 684       45  16760646
# 688     1050   9914412
# 689     1050   9914412
# 690      223  11647372
# 691      266   9910224
#
# [420 rows x 2 columns]

# %%
# merge gdsc dataset with drug on 'DRUG_ID' column
gdsc_ic50_pubchem = pd.merge(gdsc_ic50, drug_clean, on = ['DRUG_ID'], how = 'left')

# %%
gdsc_ic50_pubchem
# Out:
#           DRUG_NAME  DRUG_ID  COSMIC_ID        CCLE_Name  TSPAN6 (7105)  \
# 0       Doxorubicin      133     909907    ZR7530_BREAST       3.472488
# 1         Etoposide      134     909907    ZR7530_BREAST       3.472488
# 2       Gemcitabine      135     909907    ZR7530_BREAST       3.472488
# 3       Mitomycin-C      136     909907    ZR7530_BREAST       3.472488
# 4       Vinorelbine      140     909907    ZR7530_BREAST       3.472488
# ...             ...      ...        ...              ...            ...
# 18108    Pictilisib     1527     908121  MDAMB361_BREAST       1.855990
# 18109  Pevonedistat     1529     908121  MDAMB361_BREAST       1.855990
# 18110  Pevonedistat     1529     908121  MDAMB361_BREAST       1.855990
# 18111         PFI-3     1530     908121  MDAMB361_BREAST       1.855990
# 18112      I-CBP112     1531     908121  MDAMB361_BREAST       1.855990
#
#        TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  C1orf112 (55732)  FGR (2268)  \
# ...

# %%
# drop the NaN value
gdsc_ic50_pubchem = gdsc_ic50_pubchem.dropna(axis= 'index')

# %%
# drop the duplicate data
gdsc_ic50_pubchem = gdsc_ic50_pubchem.drop_duplicates()

# %%
gdsc_ic50_pubchem
# Out:
#           DRUG_NAME  DRUG_ID  COSMIC_ID        CCLE_Name  TSPAN6 (7105)  \
# 0       Doxorubicin      133     909907    ZR7530_BREAST       3.472488
# 1         Etoposide      134     909907    ZR7530_BREAST       3.472488
# 2       Gemcitabine      135     909907    ZR7530_BREAST       3.472488
# 3       Mitomycin-C      136     909907    ZR7530_BREAST       3.472488
# 4       Vinorelbine      140     909907    ZR7530_BREAST       3.472488
# ...             ...      ...        ...              ...            ...
# 18105  Bicalutamide     1502     908121  MDAMB361_BREAST       1.855990
# 18107   Refametinib     1526     908121  MDAMB361_BREAST       1.855990
# 18108    Pictilisib     1527     908121  MDAMB361_BREAST       1.855990
# 18109  Pevonedistat     1529     908121  MDAMB361_BREAST       1.855990
# 18111         PFI-3     1530     908121  MDAMB361_BREAST       1.855990
#
#        TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  C1orf112 (55732)  FGR (2268)  \
# ...

# %% [markdown]
# Preprocessing of PubChem

# %%
compound_data_raw = pd.read_csv("")
